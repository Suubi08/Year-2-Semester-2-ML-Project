# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
df = pd.read_csv("data.csv")
df.head()
# Out:
#                     datetime  device_name frequency   humidity  latitude  \
# 0  2025-08-31 21:00:00+00:00  airqo_g5339    hourly  80.891667       0.0
# 1  2025-08-31 21:00:00+00:00        aq_45    hourly   0.000000       0.0
# 2  2025-08-31 21:00:00+00:00      aq_g501    hourly   0.000000       0.0
# 3  2025-08-31 21:00:00+00:00      aq_g506    hourly   0.000000       0.0
# 4  2025-08-31 21:00:00+00:00  airqo_g5341    hourly  69.198846       0.0
#
#    longitude network  pm2_5  pm2_5_calibrated_value  \
# 0        0.0   airqo  13.29                   13.29
# 1        0.0   airqo  21.39                   21.39
# 2        0.0   airqo  49.56                   49.56
# 3        0.0   airqo  91.19                   91.19
# 4        0.0   airqo  42.35                   42.35
#
#                                 site_name  temperature
# 0  Makerere University Weather Station 94    20.100000
# 1                          Kasubi, Rubaga     0.000000
# ...

# %% [markdown]
# __Data cleaning__

# %%
# Loading the data
df = pd.read_csv('data.csv')

# Focusing on one site for better accuracy
df_mak = df[df['site_name'] == 'Makerere University Weather Station 94'].copy()

# Converting datetime to actual pandas datetime objects
df_mak['datetime'] = pd.to_datetime(df_mak['datetime'])

# Handle the "Zero" issue in Temp and Humidity
# We replace 0 with 'None' then fill them with the previous valid value (forward fill)
df_mak['temperature'] = df_mak['temperature'].replace(0, np.nan).ffill()
df_mak['humidity'] = df_mak['humidity'].replace(0, np.nan).ffill()

# Droping rows where the target (PM2.5) is missing
df_mak = df_mak.dropna(subset=['pm2_5_calibrated_value'])

# Keeping only the columns needed for the ML model
clean_data = df_mak[['datetime', 'humidity', 'temperature', 'pm2_5_calibrated_value']]

print(f"Cleaned data has {len(clean_data)} rows.")
clean_data.head()
# Out:
# Cleaned data has 8017 rows.
#                    datetime   humidity  temperature  pm2_5_calibrated_value
# 0 2025-08-31 21:00:00+00:00  80.891667    20.100000                   13.29
# 2 2025-08-31 21:00:00+00:00  80.891667    20.100000                   49.56
# 3 2025-08-31 21:00:00+00:00  80.891667    20.100000                   91.19
# 4 2025-08-31 21:00:00+00:00  69.198846    28.543462                   42.35
# 5 2025-08-31 22:00:00+00:00  69.198846    28.543462                   18.00

# %% [markdown]
# # Feature Engineering
# This is basically done because in the data we extracted we captured time so we assumed that adding the Hour of day column in our data set will make our model smarter. Since in Kampala, pollution usually peaks around 7:00 - 9:00 due to morning traffic and 7:00PM - 9:00PM Evening commute and cooking fires

# %%
# FIX DUPLICATES: Group by hour and take the mean of all sensors at that site
#This merges different rows into one single average row
final_df = df_mak.groupby('datetime').agg({
    'pm2_5_calibrated_value': 'mean',
    'humidity': 'mean',
    'temperature': 'mean'
}).reset_index()

# Handle zeros (Kampala isn't 0 degrees!)
final_df['temperature'] = final_df['temperature'].replace(0, np.nan).ffill()
final_df['humidity'] = final_df['humidity'].replace(0, np.nan).ffill()

# Add our "Time Series" features
final_df['hour'] = final_df['datetime'].dt.hour
final_df['day_of_week'] = final_df['datetime'].dt.dayofweek
final_df['pm25_lag_1h'] = final_df['pm2_5_calibrated_value'].shift(1)

# MORE FEATURE ENGINEERING: 
# Add 'Seasonal' features
#High humidity during the day is different than high humidity at night
final_df['temp_hum_interaction'] = final_df['temperature'] * final_df['humidity']

# Add 'Rolling' averages (The model sees the trend, not just the moment)
final_df['pm25_rolling_3h'] = final_df['pm2_5_calibrated_value'].rolling(window=3).mean()
final_df['pm25_rolling_12h'] = final_df['pm2_5_calibrated_value'].rolling(window=12).mean()


# Final Clean: Drop the one NaN row created by the shift
final_df = final_df.dropna()


print(final_df.head())
# Out:
#                     datetime  pm2_5_calibrated_value   humidity  temperature  \
# 11 2025-09-01 08:00:00+00:00               22.740000  61.258334    26.316666
# 12 2025-09-01 09:00:00+00:00               39.855000  56.941667    26.875000
# 13 2025-09-01 10:00:00+00:00               14.747500  56.025556    26.701250
# 14 2025-09-01 11:00:00+00:00               15.853333  55.506297    26.637778
# 15 2025-09-01 12:00:00+00:00               44.082500  58.316000    26.709000
#
#     hour  day_of_week  pm25_lag_1h  temp_hum_interaction  pm25_rolling_3h  \
# 11     8            0    28.560000           1612.115131        30.513333
# 12     9            0    22.740000           1530.307293        30.385000
# 13    10            0    39.855000           1495.952366        25.780833
# 14    11            0    14.747500           1478.564398        23.485278
# 15    12            0    15.853333           1557.562046        24.894444
#
#     pm25_rolling_12h
# 11         28.166528
# ...

# %%
# function that returns performance evaluation metrics
def regression_metrics(y_true, y_pred):
    mae = round(mean_absolute_error(y_true, y_pred), 2)
    mse = round(mean_squared_error(y_true, y_pred), 2)
    mape = round(mean_absolute_percentage_error(y_true, y_pred), 2)
    r2 = round(r2_score(y_true, y_pred), 2)
    return {"MAE": mae, "MSE": mse, "MAPE": mape, "R2": r2}

# %% [markdown]
# __Linear Regression__

# %%
#Definining features
#We use humidity, temp, hour and the 'lag' (previous hour's pollution)
X = final_df[['humidity', 'temperature', 'hour', 'day_of_week', 
                       'pm25_lag_1h', 'temp_hum_interaction', 
                       'pm25_rolling_3h', 'pm25_rolling_12h']]
y = final_df['pm2_5_calibrated_value']

# Time Series Split: We take the first 80% for training and last 20% for testing
# Note: We do NOT shuffle because it is time series!
split_index = int(len(final_df) * 0.8)
X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]

#Create and Train the model
baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)

#Make Predictions
predictions = baseline_model.predict(X_test)

#Evaluate
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
lr_metrics = regression_metrics(y_test, predictions)

print(f"--- Baseline Linear Regression ---")
print(f"Mean Absolute Error: {mae:.2f} ug/m3")
print(f"R-squared Score: {r2:.4f}")
print(lr_metrics)
# Out:
# --- Baseline Linear Regression ---
# Mean Absolute Error: 6.74 ug/m3
# R-squared Score: 0.7083
# {'MAE': 6.74, 'MSE': 97.96, 'MAPE': 0.33, 'R2': 0.71}

# %%
# Initilize the random forest
# with n_estimators=100
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model (using the same X_train and y_train from before)
rf_model.fit(X_train, y_train)

#Make Predictions
rf_predictions = rf_model.predict(X_test)

#Determine the metrics
rf_results = regression_metrics(y_test, rf_predictions)

print("--- Intermediate: Random Forest Regressor ---")
print(rf_results)

# Let's compare R2 score directly
print(f"\nImprovement in R2: {rf_results['R2'] - 0.71:.2f}")
# Out:
# --- Intermediate: Random Forest Regressor ---
# {'MAE': 6.77, 'MSE': 99.8, 'MAPE': 0.33, 'R2': 0.7}
#
# Improvement in R2: -0.01

# %% [markdown]
# # Model visualizations

# %% [markdown]
# ### Feature Importance Visualization

# %%
# Getting the importance from the Random Forest Model
importances = rf_model.feature_importances_
feature_names = X.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=True)

#Plotting
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='skyblue')
plt.title('Feature Importance: What drives PM2.5 in Kampala?')
plt.xlabel('Importance Score')
plt.show()

# %% [markdown]
# #### Report
# After Plotting the feature importance, we found that the 3 hour rolling average was the most significant predictor.This suggests high temporal autocorrelation in Kampala's air quality, where the immediate history of the atmosphere is more influential than individual weather variables at a single point in time.
# ##### Why Humidity and Temperature so low?
# We assumed that temperature and humidy are low because they are implicilty captured within the rolling averages. That our model prioritizes the aggregated trend over individual raw weather inputs.

# %% [markdown]
# #### Correlation Heatmap

# %%
# Select only the numeric columns we care about
cols_to_corr = ['pm2_5_calibrated_value', 'humidity', 'temperature', 
                'hour', 'pm25_lag_1h', 'pm25_rolling_3h']

# Calculate the correlation matrix
corr_matrix = final_df[cols_to_corr].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='RdYlGn', center=0, fmt=".2f")
plt.title('Correlation Matrix: Feature Relationships')
plt.show()

# %% [markdown]
# #### Explanation
# ##### Example:
# Look at where __Pm2_5_calibrated_value__ meets __pm25_rolling_3h.__ The score is __0.83.__
# __Interpretation__: This is a very strong positive correlation. It mathematically confirms what our Feature Importance chart showed: that the current air quality is heavily dictated by the average of the last three hours.
#
#
#
#
#
#
# .

# %% [markdown]
# ### The TRUTH PLOT
# #### Model Performance Analysis: Actual vs Predicted PM2.5
# This visualization compares the actual calibrated __PM2.5__ readings from the Makerere Weather Station against the __Random Forest Regressor's__ predictions over a 100-hour test window

# %%
plt.figure(figsize=(15, 6))
plt.plot(y_test.values[:100], label='Actual PM2.5', color='black', linewidth=1.5)
plt.plot(rf_predictions[:100], label='RF Predicted PM2.5', color='red', linestyle='--', linewidth=1.5)
plt.title('Actual vs Predicted PM2.5 (First 100 Test Hours)')
plt.ylabel('PM2.5 Concentration')
plt.legend()
plt.show()

# %% [markdown]
# #### Key Observations:
# __Temporal Synchronization:__ The model demostrates excellent "phase tracking," meaning it accurately predicts the __start and end times__ of pollution spikes. This means that the engineered Temporal Features (Lag and Rolling Means) successifully captured the city's air quality variation rythms.
#
# __Trend Fidelity:__ Throughout the periods of lower pollution, the predicted values align almost perfectly with the actual data, contributing to the strong __R2 Score of 0.71.__
#
# __Peak Sensitivity:__ While the model captures the existence of extreme pollution events, it exhibits a slight "Conservation bias" during the highest spikes. This is a characteristic of ensemble tree models which tend to predict toward the historical mean when faced with rare extremes.
#
# __Conclusion:__ The model is highly reliable for general air quality forecasting and trend analysis, effectively translating meteorological and historical inputs into actionable pollution insights.
